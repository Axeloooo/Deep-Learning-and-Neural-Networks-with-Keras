# %% [markdown]
# # Regression Models with Keras

# %% [markdown]
# ## Introduction

# %% [markdown]
# Despite the popularity of more powerful libraries such as PyToch and TensorFlow, they are not easy to use and have a steep learning curve. So, for people who are just starting to learn deep learning, there is no better library to use other than the Keras library.
#
# Keras is a high-level API for building deep learning models. It has gained favor for its ease of use and syntactic simplicity facilitating fast development. As you will see in this lab and the other labs in this course, building a very complex deep learning network can be achieved with Keras with only few lines of code. You will appreciate Keras even more, once you learn how to build deep models using PyTorch and TensorFlow.
#
# So, in this lab, you will learn how to use the Keras library to build a regression model.

# %% [markdown]
# ## Objectives for this Notebook
# * How to use the Keras library to build a regression model
# * Download and clean the data set
# * Build a neural network
# * Train and test the network

# %% [markdown]
# ## Table of Contents
#
# 1. [Download and Clean the Data Set](#Download-and-Clean-the-Data-Set)
# 2. [Import Keras Packages](#Import-Keras-Packages)
# 3. [Build a Neural Network](#Build-a-Neural-Network)
# 4. [Train and Test the Network](#Train-and-Test-the-Network)

# %% [markdown]
# Let's start by importing the <em>pandas</em> and the Numpy libraries.

# %%
# All Libraries required for this lab are listed below. 

#!pip install numpy==2.0.2
#!pip install pandas==2.2.2
#!pip install tensorflow_cpu==2.18.0

# %% [markdown]
# #### To use Keras, you will also need to install a backend framework – such as TensorFlow.
#
# If you install TensorFlow 2.16 or above, it will install Keras by default.
#
# We are using the CPU version of tensorflow since we are dealing with smaller datasets.
# You may install the GPU version of tensorflow on your machine to accelarate the processing of larger datasets

# %% [markdown]
# #### Suppress the tensorflow warning messages
# We use the following code to  suppress the warning messages due to use of CPU architechture for tensoflow.
#
# You may want to **comment out** these lines if you are using the GPU architechture

# %%
import os
os.environ['TF_ENABLE_ONEDNN_OPTS'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

# %%
import pandas as pd
import numpy as np
import keras

import warnings
warnings.simplefilter('ignore', FutureWarning)

# %% [markdown]
# <strong>The dataset is about the compressive strength of different samples of concrete based on the volumes of the different ingredients that were used to make them. Ingredients include:</strong>
#
# * Cement
# * Blast furnace slag
# * Fly ash
# * Water
# * Superplasticizer
# * Coarse aggregate
# * Fine aggregate

# %% [markdown]
# ## Download and Clean the Data Set

# %% [markdown]
# Let's download the data and read it into a <em>pandas</em> dataframe.

# %%
filepath='https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv'
concrete_data = pd.read_csv(filepath)

concrete_data.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89
# 2             932.0           594.0  270     40.27
# 3             932.0           594.0  365     41.05
# 4             978.4           825.5  360     44.30

# %% [markdown]
# So the first concrete sample has 540 cubic meter of cement, 0 cubic meter of blast furnace slag, 0 cubic meter of fly ash, 162 cubic meter of water, 2.5 cubic meter of superplaticizer, 1040 cubic meter of coarse aggregate, 676 cubic meter of fine aggregate. Such a concrete mix which is 28 days old, has a compressive strength of 79.99 MPa.

# %% [markdown]
# #### Let's check how many data points we have

# %%
concrete_data.shape
# Out:
# (1030, 9)

# %% [markdown]
# So, there are approximately 1000 samples to train our model on. Because of the few samples, we have to be careful not to overfit the training data.

# %% [markdown]
# Let's check the dataset for any missing values.

# %%
concrete_data.describe()
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
concrete_data.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# The data looks very clean and is ready to be used to build our model.

# %% [markdown]
# #### Split data into predictors and target

# %% [markdown]
# The target variable in this problem is the concrete sample strength. Therefore, our predictors will be all the other columns.

# %%
concrete_data_columns = concrete_data.columns

# %%
predictors = concrete_data[concrete_data_columns[concrete_data_columns != 'Strength']] # all columns except Strength
target = concrete_data['Strength'] # Strength column

# %% [markdown]
# Let's do a quick sanity check of the predictors and the target dataframes.

# %%
predictors.head()
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
# 4   198.6               132.4      0.0  192.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365
# 4             978.4           825.5  360

# %%
target.head()
# Out:
# 0    79.99
# 1    61.89
# 2    40.27
# 3    41.05
# 4    44.30
# Name: Strength, dtype: float64

# %% [markdown]
# Finally, the last step is to normalize the data by substracting the mean and dividing by the standard deviation.

# %%
predictors_norm = (predictors - predictors.mean()) / predictors.std()
predictors_norm.head()
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 4 -0.790075            0.678079 -0.846733  0.488555         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221
# 4          0.070492        0.647569  4.976069

# %% [markdown]
# Let's save the number of predictors to *n_cols* since we will need this number when building our network.

# %%
n_cols = predictors_norm.shape[1] # number of predictors

# %% [markdown]
# <a id="item1"></a>

# %% [markdown]
# ##  Import Keras Packages
#
# ##### Let's import the rest of the packages from the Keras library that we will need to build our regression model.

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Input

# %% [markdown]
# ## Build a Neural Network

# %% [markdown]
# Let's define a function that defines our regression model for us so that we can conveniently call it to create our model.

# %%
# define regression model
def regression_model():
    # create model
    model = Sequential()
    model.add(Input(shape=(n_cols,)))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1))
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
# The above function create a model that has two hidden layers, each of 50 hidden units.

# %% [markdown]
# ## Train and Test the Network

# %% [markdown]
# Let's call the function now to create our model.

# %%
# build the model
model = regression_model()

# %% [markdown]
# Next, we will train and test the model at the same time using the *fit* method. We will leave out 30% of the data for validation and we will train the model for 100 epochs.

# %%
# fit the model
model.fit(predictors_norm, target, validation_split=0.3, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 23/23 - 1s - 57ms/step - loss: 1613.7657 - val_loss: 1102.1763
# Epoch 2/100
# 23/23 - 0s - 19ms/step - loss: 1451.9606 - val_loss: 943.7097
# Epoch 3/100
# 23/23 - 0s - 13ms/step - loss: 1200.5770 - val_loss: 720.9549
# Epoch 4/100
# 23/23 - 0s - 9ms/step - loss: 854.3256 - val_loss: 471.9664
# Epoch 5/100
# 23/23 - 0s - 13ms/step - loss: 504.6215 - val_loss: 277.3734
# Epoch 6/100
# 23/23 - 0s - 13ms/step - loss: 290.4366 - val_loss: 191.8919
# Epoch 7/100
# 23/23 - 0s - 11ms/step - loss: 230.9466 - val_loss: 175.1895
# Epoch 8/100
# 23/23 - 0s - 10ms/step - loss: 213.0116 - val_loss: 169.2143
# Epoch 9/100
# 23/23 - 0s - 13ms/step - loss: 202.7902 - val_loss: 161.9776
# Epoch 10/100
# 23/23 - 0s - 10ms/step - loss: 193.9464 - val_loss: 162.6505
# Epoch 11/100
# 23/23 - 0s - 7ms/step - loss: 188.0013 - val_loss: 164.9737
# Epoch 12/100
# 23/23 - 0s - 6ms/step - loss: 182.5052 - val_loss: 163.2758
# Epoch 13/100
# 23/23 - 0s - 6ms/step - loss: 177.2581 - val_loss: 161.8380
# Epoch 14/100
# 23/23 - 0s - 6ms/step - loss: 173.0754 - val_loss: 159.2115
# Epoch 15/100
# 23/23 - 0s - 6ms/step - loss: 168.9949 - val_loss: 159.4305
# Epoch 16/100
# 23/23 - 0s - 6ms/step - loss: 165.9885 - val_loss: 156.8696
# Epoch 17/100
# 23/23 - 0s - 13ms/step - loss: 45.0496 - val_loss: 120.9305
# Epoch 83/100
# 23/23 - 0s - 13ms/step - loss: 44.7833 - val_loss: 132.1717
# Epoch 84/100
# 23/23 - 0s - 13ms/step - loss: 44.0060 - val_loss: 129.0835
# Epoch 85/100
# 23/23 - 0s - 9ms/step - loss: 43.0902 - val_loss: 136.0573
# Epoch 86/100
# 23/23 - 0s - 10ms/step - loss: 42.9225 - val_loss: 121.5018
# Epoch 87/100
# 23/23 - 0s - 12ms/step - loss: 42.4045 - val_loss: 128.6855
# Epoch 88/100
# 23/23 - 0s - 9ms/step - loss: 41.5419 - val_loss: 120.1090
# Epoch 89/100
# 23/23 - 0s - 10ms/step - loss: 41.3415 - val_loss: 128.2275
# Epoch 90/100
# 23/23 - 0s - 11ms/step - loss: 41.0991 - val_loss: 138.4061
# Epoch 91/100
# 23/23 - 0s - 10ms/step - loss: 40.0989 - val_loss: 137.9615
# Epoch 92/100
# 23/23 - 0s - 6ms/step - loss: 39.5036 - val_loss: 133.2495
# Epoch 93/100
# 23/23 - 0s - 6ms/step - loss: 39.0417 - val_loss: 124.1181
# Epoch 94/100
# 23/23 - 0s - 6ms/step - loss: 38.7749 - val_loss: 142.3182
# Epoch 95/100
# 23/23 - 0s - 6ms/step - loss: 38.2926 - val_loss: 133.9986
# Epoch 96/100
# 23/23 - 0s - 6ms/step - loss: 37.7596 - val_loss: 139.4084
# Epoch 97/100
# 23/23 - 0s - 6ms/step - loss: 37.6325 - val_loss: 137.5307
# Epoch 98/100
# 23/23 - 0s - 13ms/step - loss: 37.0543 - val_loss: 137.1825
# Epoch 99/100
# 23/23 - 0s - 6ms/step - loss: 36.6905 - val_loss: 132.4092
# Epoch 100/100
# 23/23 - 0s - 6ms/step - loss: 36.6971 - val_loss: 132.4459

# %% [markdown]
# <strong>You can refer to this [link](https://keras.io/models/sequential/) to learn about other functions that you can use for prediction or evaluation.</strong>

# %% [markdown]
# Feel free to vary the following and note what impact each change has on the model's performance:
#
# 1. Increase or decreate number of neurons in hidden layers
# 2. Add more hidden layers
# 3. Increase number of epochs

# %% [markdown]
# Now using the same dateset,try to recreate regression model featuring five hidden layers, each with 50 nodes and ReLU activation functions, a single output layer, optimized using the Adam optimizer.

# %%
def regression_model():
    input_colm = predictors_norm.shape[1] # Number of input features
    # create model
    model = Sequential()
    model.add(Input(shape=(input_colm,)))  # Set the number of input features 
    model.add(Dense(50, activation='relu'))  
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu')) 
    model.add(Dense(50, activation='relu'))
    model.add(Dense(50, activation='relu'))  
    model.add(Dense(1))  # Output layer
    
    # compile model
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

# %% [markdown]
#  Train and evaluate the model simultaneously using the fit() method by reserving 10% of the data for validation and training the model for 100 epochs

# %%
# build the model
model = regression_model()
model.fit(predictors_norm, target, validation_split=0.1, epochs=100, verbose=2)
# Out:
# Epoch 1/100
# 29/29 - 2s - 60ms/step - loss: 1483.7565 - val_loss: 892.6688
# Epoch 2/100
# 29/29 - 0s - 5ms/step - loss: 601.7770 - val_loss: 287.7502
# Epoch 3/100
# 29/29 - 0s - 5ms/step - loss: 240.8770 - val_loss: 210.3074
# Epoch 4/100
# 29/29 - 0s - 5ms/step - loss: 194.7299 - val_loss: 186.8376
# Epoch 5/100
# 29/29 - 0s - 6ms/step - loss: 177.1027 - val_loss: 175.8985
# Epoch 6/100
# 29/29 - 0s - 5ms/step - loss: 161.6706 - val_loss: 168.6527
# Epoch 7/100
# 29/29 - 0s - 5ms/step - loss: 147.9786 - val_loss: 137.7985
# Epoch 8/100
# 29/29 - 0s - 5ms/step - loss: 137.8305 - val_loss: 122.0521
# Epoch 9/100
# 29/29 - 0s - 5ms/step - loss: 122.2403 - val_loss: 126.4539
# Epoch 10/100
# 29/29 - 0s - 5ms/step - loss: 108.8399 - val_loss: 100.2913
# Epoch 11/100
# 29/29 - 0s - 5ms/step - loss: 97.0402 - val_loss: 89.4373
# Epoch 12/100
# 29/29 - 0s - 6ms/step - loss: 86.4749 - val_loss: 68.0368
# Epoch 13/100
# 29/29 - 0s - 5ms/step - loss: 77.1912 - val_loss: 66.7094
# Epoch 14/100
# 29/29 - 0s - 5ms/step - loss: 69.2867 - val_loss: 64.7066
# Epoch 15/100
# 29/29 - 0s - 5ms/step - loss: 62.6857 - val_loss: 53.7124
# Epoch 16/100
# 29/29 - 0s - 5ms/step - loss: 56.2697 - val_loss: 52.9585
# Epoch 17/100
# 29/29 - 0s - 5ms/step - loss: 52.6402 - val_loss: 44.3773
# Epoch 18/100
# 29/29 - 0s - 5ms/step - loss: 48.9919 - val_loss: 46.0370
# Epoch 19/100
# 29/29 - 0s - 6ms/step - loss: 46.3716 - val_loss: 43.6213
# Epoch 20/100
# 29/29 - 0s - 5ms/step - loss: 45.4758 - val_loss: 45.5261
# Epoch 21/100
# 29/29 - 0s - 5ms/step - loss: 41.9748 - val_loss: 39.7580
# Epoch 22/100
# 29/29 - 0s - 5ms/step - loss: 39.8559 - val_loss: 35.6439
# Epoch 23/100
# 29/29 - 0s - 5ms/step - loss: 35.9086 - val_loss: 38.3915
# Epoch 24/100
# 29/29 - 0s - 5ms/step - loss: 35.7793 - val_loss: 32.7881
# Epoch 25/100
# 29/29 - 0s - 5ms/step - loss: 33.1902 - val_loss: 37.6821
# Epoch 26/100
# 29/29 - 0s - 10ms/step - loss: 31.0717 - val_loss: 33.3231
# Epoch 27/100
# 29/29 - 0s - 5ms/step - loss: 30.0585 - val_loss: 27.5556
# Epoch 28/100
# 29/29 - 0s - 5ms/step - loss: 29.3813 - val_loss: 28.2052
# Epoch 29/100
# 29/29 - 0s - 5ms/step - loss: 29.0528 - val_loss: 27.8095
# Epoch 30/100
# 29/29 - 0s - 5ms/step - loss: 28.1566 - val_loss: 35.7183
# Epoch 31/100
# 29/29 - 0s - 6ms/step - loss: 27.2930 - val_loss: 28.2240
# Epoch 32/100
# 29/29 - 0s - 5ms/step - loss: 25.8209 - val_loss: 28.7558
# Epoch 33/100
# 29/29 - 0s - 5ms/step - loss: 25.1538 - val_loss: 26.5805
# Epoch 34/100
# 29/29 - 0s - 5ms/step - loss: 23.2655 - val_loss: 28.8970
# Epoch 35/100
# 29/29 - 0s - 5ms/step - loss: 22.4005 - val_loss: 24.1211
# Epoch 36/100
# 29/29 - 0s - 5ms/step - loss: 22.1649 - val_loss: 25.9617
# Epoch 37/100
# 29/29 - 0s - 5ms/step - loss: 21.8797 - val_loss: 23.4728
# Epoch 38/100
# 29/29 - 0s - 6ms/step - loss: 24.3860 - val_loss: 24.1324
# Epoch 39/100
# 29/29 - 0s - 5ms/step - loss: 22.2627 - val_loss: 24.6005
# Epoch 40/100
# 29/29 - 0s - 5ms/step - loss: 20.8522 - val_loss: 28.4093
# Epoch 41/100
# 29/29 - 0s - 5ms/step - loss: 19.5884 - val_loss: 23.4358
# Epoch 42/100
# 29/29 - 0s - 5ms/step - loss: 19.5208 - val_loss: 24.7353
# Epoch 43/100
# 29/29 - 0s - 5ms/step - loss: 19.6756 - val_loss: 24.4098
# Epoch 44/100
# 29/29 - 0s - 7ms/step - loss: 18.7450 - val_loss: 27.4016
# Epoch 45/100
# 29/29 - 0s - 11ms/step - loss: 20.8270 - val_loss: 22.1226
# Epoch 46/100
# 29/29 - 0s - 8ms/step - loss: 18.4715 - val_loss: 22.6602
# Epoch 47/100
# 29/29 - 0s - 8ms/step - loss: 18.0863 - val_loss: 24.7647
# Epoch 48/100
# 29/29 - 0s - 11ms/step - loss: 17.6640 - val_loss: 21.3993
# Epoch 49/100
# 29/29 - 0s - 9ms/step - loss: 18.2968 - val_loss: 22.8164
# Epoch 50/100
# 29/29 - 0s - 11ms/step - loss: 17.4489 - val_loss: 23.5802
# Epoch 51/100
# 29/29 - 0s - 8ms/step - loss: 16.4896 - val_loss: 24.9558
# Epoch 52/100
# 29/29 - 0s - 8ms/step - loss: 17.7892 - val_loss: 23.1844
# Epoch 53/100
# 29/29 - 0s - 11ms/step - loss: 16.3127 - val_loss: 20.1765
# Epoch 54/100
# 29/29 - 0s - 8ms/step - loss: 16.6862 - val_loss: 25.7946
# Epoch 55/100
# 29/29 - 0s - 8ms/step - loss: 16.6196 - val_loss: 24.6135
# Epoch 56/100
# 29/29 - 0s - 8ms/step - loss: 15.8281 - val_loss: 19.9419
# Epoch 57/100
# 29/29 - 0s - 10ms/step - loss: 15.5897 - val_loss: 22.4256
# Epoch 58/100
# 29/29 - 0s - 5ms/step - loss: 15.4099 - val_loss: 21.3185
# Epoch 59/100
# 29/29 - 0s - 6ms/step - loss: 15.2990 - val_loss: 20.2177
# Epoch 60/100
# 29/29 - 0s - 5ms/step - loss: 14.8285 - val_loss: 26.0413
# Epoch 61/100
# 29/29 - 0s - 5ms/step - loss: 16.0441 - val_loss: 19.4476
# Epoch 62/100
# 29/29 - 0s - 6ms/step - loss: 14.6932 - val_loss: 19.8314
# Epoch 63/100
# 29/29 - 0s - 5ms/step - loss: 16.0603 - val_loss: 25.1832
# Epoch 64/100
# 29/29 - 0s - 5ms/step - loss: 14.7024 - val_loss: 20.3386
# Epoch 65/100
# 29/29 - 0s - 5ms/step - loss: 14.0760 - val_loss: 24.2174
# Epoch 66/100
# 29/29 - 0s - 5ms/step - loss: 15.1397 - val_loss: 18.3373
# Epoch 67/100
# 29/29 - 0s - 5ms/step - loss: 14.0936 - val_loss: 19.6994
# Epoch 68/100
# 29/29 - 0s - 5ms/step - loss: 13.1320 - val_loss: 17.9843
# Epoch 69/100
# 29/29 - 0s - 6ms/step - loss: 14.0158 - val_loss: 18.1589
# Epoch 70/100
# 29/29 - 0s - 10ms/step - loss: 13.4608 - val_loss: 21.2797
# Epoch 71/100
# 29/29 - 0s - 5ms/step - loss: 13.8229 - val_loss: 18.3206
# Epoch 72/100
# 29/29 - 0s - 5ms/step - loss: 13.4200 - val_loss: 20.4179
# Epoch 73/100
# 29/29 - 0s - 5ms/step - loss: 14.4244 - val_loss: 16.4073
# Epoch 74/100
# 29/29 - 0s - 5ms/step - loss: 13.4286 - val_loss: 17.0405
# Epoch 75/100
# 29/29 - 0s - 6ms/step - loss: 14.6139 - val_loss: 20.3265
# Epoch 76/100
# 29/29 - 0s - 10ms/step - loss: 12.6049 - val_loss: 18.2398
# Epoch 77/100
# 29/29 - 0s - 5ms/step - loss: 12.0107 - val_loss: 17.1817
# Epoch 78/100
# 29/29 - 0s - 5ms/step - loss: 12.8853 - val_loss: 17.0896
# Epoch 79/100
# 29/29 - 0s - 5ms/step - loss: 14.3738 - val_loss: 20.5229
# Epoch 80/100
# 29/29 - 0s - 5ms/step - loss: 14.4922 - val_loss: 19.5803
# Epoch 81/100
# 29/29 - 0s - 6ms/step - loss: 13.1675 - val_loss: 18.3454
# Epoch 82/100
# 29/29 - 0s - 5ms/step - loss: 12.6715 - val_loss: 16.7684
# Epoch 83/100
# 29/29 - 0s - 5ms/step - loss: 12.2065 - val_loss: 16.1495
# Epoch 84/100
# 29/29 - 0s - 5ms/step - loss: 12.2444 - val_loss: 16.6852
# Epoch 85/100
# 29/29 - 0s - 5ms/step - loss: 12.8222 - val_loss: 16.7138
# Epoch 86/100
# 29/29 - 0s - 5ms/step - loss: 11.4631 - val_loss: 15.8826
# Epoch 87/100
# 29/29 - 0s - 5ms/step - loss: 13.5374 - val_loss: 17.9450
# Epoch 88/100
# 29/29 - 0s - 6ms/step - loss: 11.5045 - val_loss: 15.2188
# Epoch 89/100
# 29/29 - 0s - 10ms/step - loss: 12.7942 - val_loss: 14.9524
# Epoch 90/100
# 29/29 - 0s - 5ms/step - loss: 13.0062 - val_loss: 16.6341
# Epoch 91/100
# 29/29 - 0s - 5ms/step - loss: 11.8989 - val_loss: 15.6367
# Epoch 92/100
# 29/29 - 0s - 5ms/step - loss: 11.2412 - val_loss: 17.0981
# Epoch 93/100
# 29/29 - 0s - 5ms/step - loss: 11.9700 - val_loss: 15.7888
# Epoch 94/100
# 29/29 - 0s - 11ms/step - loss: 10.8371 - val_loss: 16.2773
# Epoch 95/100
# 29/29 - 0s - 5ms/step - loss: 10.3481 - val_loss: 14.3988
# Epoch 96/100
# 29/29 - 0s - 5ms/step - loss: 10.8214 - val_loss: 15.7255
# Epoch 97/100
# 29/29 - 0s - 5ms/step - loss: 10.9695 - val_loss: 18.5576
# Epoch 98/100
# 29/29 - 0s - 5ms/step - loss: 12.3587 - val_loss: 21.4776
# Epoch 99/100
# 29/29 - 0s - 5ms/step - loss: 10.8082 - val_loss: 14.4714
# Epoch 100/100
# 29/29 - 0s - 5ms/step - loss: 11.2763 - val_loss: 14.5266

# %% [markdown]
# Based on the results, we notice that:
#
# - Adding more hidden layers to the model increases its capacity to learn and represent complex relationships within the data. This allows the model to better identify, as a result, the model becomes more effective at fitting the training data and potentially improving its predictions.
# - By reducing the proportion of data set aside for validation and using a larger portion for training, the model has access to more examples to learn from. This additional training data helps the model improve its understanding of the underlying trends, which can lead to better overall performance.
